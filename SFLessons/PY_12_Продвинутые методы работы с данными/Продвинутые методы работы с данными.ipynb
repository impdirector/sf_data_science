# %%
import pandas as pd

# %%
melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
# Out:
# Date
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: count, dtype: int64

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_df.sort_values(by=['Price', 'Distance'], ascending=False).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 12094      18.8  9000000.0
# 9179        5.3  5510000.0
# 7684        7.8  5020000.0
# 3788        7.4  4700000.0
# 1050       11.2  4250000.0
# ...         ...        ...
# 7878       10.4   260000.0
# 7168       11.8   250000.0
# 2027        7.8   241000.0
# 5205       11.2   216000.0
# 7305       13.9   190000.0
#
# [1358 rows x 2 columns]

# %%
melb_df.loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 0           2.5  1480000.0
# 10          2.5   700000.0
# 20          2.5  1330000.0
# 30          2.5  1542000.0
# 40         13.5   770000.0
# ...         ...        ...
# 13530      12.0   625500.0
# 13540      35.4   512000.0
# 13550      10.5   595000.0
# 13560      12.4  1400000.0
# 13570      14.7   970000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(by=['AreaRatio'], ascending=False, ignore_index=True).loc[1557:1559, 'BuildingArea']
# Out:
# 1557     81.0
# 1558    126.0
# 1559     72.0
# Name: BuildingArea, dtype: float64

# %%
mask_townhouse = melb_df['Type'] == 'townhouse'
mask_rooms = melb_df['Rooms'] > 2

melb_df[mask_townhouse & mask_rooms].sort_values(
    by=['Rooms', 'MeanRoomsSquare'], # сортируем по количеству комнат, потом по площади комнат
    ascending=[True, False], # по возрастанию количества комнат и по убыванию средней площади комнат
    ignore_index=True # создаем новые индексы
).loc[18, 'Price']
# Out:
# 1300000.0

# %% [markdown]
# ### 3. Группировка данных в DataFrame

# %% [markdown]
# ##### ГРУППИРОВКА ДАННЫХ ПО ОДНОМУ КРИТЕРИЮ С ОДНОЙ АГРЕГАЦИЕЙ

# %%
melb_df.groupby(by='Type', as_index=False)['Price'].mean(numeric_only=True)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/978333082.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type', as_index=False)['Price'].mean(numeric_only=True)
#         Type         Price
# 0      house  1.242665e+06
# 1  townhouse  9.337351e+05
# 2       unit  6.051275e+05

# %%
# давайте выясним, какие регионы (Regionname) наиболее удалены от центра Мельбурна
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/3363910317.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by=['max'], ascending=False)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/2087267450.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 8           1850  1.056371e+06  6500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 12           725  1.144737e+06  5700000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 1            278  9.397921e+05  5200000.0
# 11           750  1.142503e+06  5050000.0
# 2            333  1.169051e+06  4735000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe').sort_values(by='25%', ascending=False)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/431138962.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe').sort_values(by='25%', ascending=False)
#             count          mean            std       min       25%        50%  \
# MonthSale
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# 12          725.0  1.144737e+06  706549.007161  250000.0  667500.0   938000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/1626580071.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['SellerG'].agg(
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Marshall, Ray, Noel, hockingstuart, other, Pu...
# Eastern Victoria            {hockingstuart, Barry, McGrath, HAR, O'Brien, ...
# ...

# %%
melb_df.groupby('Rooms')['Price'].agg('mean').sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std().sort_values(ascending=False)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/1269800844.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].std().sort_values(ascending=False)
# Regionname
# Eastern Victoria              0.147067
# Northern Victoria             0.084455
# South-Eastern Metropolitan    0.073411
# Western Metropolitan          0.051251
# Northern Metropolitan         0.049639
# Eastern Metropolitan          0.047890
# Southern Metropolitan         0.043080
# Western Victoria              0.011579
# Name: Lattitude, dtype: float64

# %%
mask_date1 = melb_df['Date'] > pd.to_datetime('2017-05-01')
mask_date2 = melb_df['Date'] < pd.to_datetime('2017-09-01')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/436509356.py in ?()
# ----> 1 mask_date1 = (melb_df['Date'] > pd.to_datetime('2017-05-01') and melb_df['Date'] < pd.to_datetime('2017-09-01'))
#       2 mask_date2 = melb_df['Date'] < pd.to_datetime('2017-09-01')
#
# ~/Documents/Python/SFProjects/sf_data_science/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
melb_df[mask_date1 & mask_date2].groupby('SellerG')['Price'].sum().sort_values()
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/690860785.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[mask_date1 & mask_date2].groupby('SellerG')['Price'].sum().sort_values()
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# ...

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/1929913328.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
# ...

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/442157687.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/3628189379.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/2235996276.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/186795090.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/186795090.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/1809242545.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                 1244000.0          780000.0
#        townhouse              760000.0               0.0
#        unit                   650000.0               0.0
# S      house                 1127000.0          675000.0
#        townhouse              828000.0               0.0
#        unit                   645750.0          492000.0
# SA     house                  932500.0          950000.0
#        townhouse              807500.0               0.0
#        unit                        0.0               0.0
# SP     house                 1050000.0          672500.0
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns=['Method','Type'],
    aggfunc='median',
    fill_value=0
)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/1570605343.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Method                             PI                               S  \
# Type                            house  townhouse      unit      house
# Regionname
# Eastern Metropolitan        1244000.0   760000.0  650000.0  1127000.0
# Eastern Victoria             780000.0        0.0       0.0   675000.0
# Northern Metropolitan        900000.0   632500.0  410000.0   920000.0
# Northern Victoria            500000.0        0.0       0.0   555000.0
# South-Eastern Metropolitan   865000.0  1190000.0  525000.0   883300.0
# Southern Metropolitan       1725000.0  1055000.0  571250.0  1611000.0
# Western Metropolitan         870000.0   670000.0  360000.0   870000.0
# ...

# %%
melb_df.pivot_table(
    values='BuildingArea',
    columns='Rooms',
    index='Type',
    aggfunc='median',
    fill_value=0
).round()
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/1289666881.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.0  126.0  126.0
# townhouse   88.0  114.0  126.0  160.0  152.0    0.0    0.0    0.0    0.0
# unit        70.0  110.0  126.0  126.0    0.0  171.0    0.0  126.0    0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
    fill_value=0
).sort_values(by='unit', ascending=False)
# Out:
# /var/folders/9t/d4bq7zb146v439lxxk1zxns00000gq/T/ipykernel_83132/302751761.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Type               house  townhouse      unit
# SellerG
# Nick           2025000.0   780000.0  900000.0
# Marshall       1975000.0  1408500.0  715000.0
# Cayzer         1505000.0  1450000.0  707500.0
# Kay            2220000.0  1365000.0  695000.0
# Noel           1400500.0   990000.0  693250.0
# Buxton         1323750.0  1030000.0  670000.0
# Fletchers      1390000.0  1238000.0  653000.0
# Chisholm       1520000.0   950000.0  640000.0
# Philip         1035000.0   701000.0  636000.0
# RT             1640000.0  1400000.0  630000.0
# C21             836500.0   768750.0  625500.0
# RW              870000.0   630500.0  625500.0
# Moonee          806000.0   715000.0  622000.0
# ...

# %%
ratings1 = pd.read_csv('data/movies_data/ratings1.csv', sep=',')
ratings2 = pd.read_csv('data/movies_data/ratings2.csv', sep=',')
dates = pd.read_csv('data/movies_data/dates.csv')
movies = pd.read_csv('data/movies_data/movies.csv', sep=',')

# %%
ratings1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40001 entries, 0 to 40000
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   40001 non-null  int64
#  1   movieId  40001 non-null  int64
#  2   rating   40001 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 937.6 KB

# %%
ratings2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60836 entries, 0 to 60835
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   60836 non-null  int64
#  1   movieId  60836 non-null  int64
#  2   rating   60836 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.4 MB

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    100836 non-null  object
# dtypes: object(1)
# memory usage: 787.9+ KB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
dates['date'] = pd.to_datetime(dates['date'])

# %%
dates['date'].dt.year.value_counts()
# Out:
# date
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: count, dtype: int64

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
ratings = ratings.drop_duplicates(ignore_index=True)

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %%
import os

path = 'data/movies_data/'
print(sorted(os.listdir(path)))
# Out:
# ['dates.csv', 'movies.csv', 'ratings1.csv', 'ratings2.csv']

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %%
a = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [103, 214, 124], 'C': [1, 4, 2]})
b = pd.DataFrame({'V': ['d', 'b', 'c'], 'U': [1393.7, 9382.2, 1904.5], 'C': [1, 3, 2]})
display(a,b)
# Out:
#    A    B  C
# 0  a  103  1
# 1  b  214  4
# 2  c  124  2
#    V       U  C
# 0  d  1393.7  1
# 1  b  9382.2  3
# 2  c  1904.5  2

# %%
a.merge(b, how='outer')
# Out:
#      A      B  C    V       U
# 0    a  103.0  1    d  1393.7
# 1    c  124.0  2    c  1904.5
# 2  NaN    NaN  3    b  9382.2
# 3    b  214.0  4  NaN     NaN

# %%
items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394],
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})

purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132],
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})

display(items_df, purchase_df)
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %%
merged = items_df.merge(purchase_df, how='inner', on='item_id')
display(merged)
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
income = (merged['stock_count'] * merged['price']).sum()
print(income)
# Out:
# 19729490
